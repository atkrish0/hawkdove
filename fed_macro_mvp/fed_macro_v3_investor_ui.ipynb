# %% [markdown]
# # Federal Reserve Macro Investor Dashboard (Interactive UI)
#
# This notebook provides a user-friendly UI on top of the same core pipeline.
# Use it to run analysis, focus on one macro topic, and inspect quote-level evidence.

# %% [markdown]
# ## 0) Install / refresh dependencies
# Run this first in a fresh environment. The command uses `requirements.txt` only (no shell redirection issues).

# %%
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1) Imports + setup
# This section keeps setup minimal and clean. UI behavior is implemented in `core/investor_ui.py`.

# %%
from pathlib import Path

from core.pipeline import create_config
from core.investor_ui import launch_investor_dashboard

cfg = create_config(Path.cwd())
print('Project dir:', cfg.project_dir)
print('Default profile:', cfg.profile_name)
# Out:
# Project dir: /Users/atheeshkrishnan/AK/DEV/hawkdove/fed_macro_mvp
# Default profile: fast_default

# %% [markdown]
# ## 2) Launch dashboard
# Use controls in the UI to choose profile, run mode, and topic focus. Click **Run** to execute and populate results.

# %%
ui = launch_investor_dashboard(cfg)
